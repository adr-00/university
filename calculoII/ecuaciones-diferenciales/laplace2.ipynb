# %%
from sympy import *

# %%
z, t, l, w = symbols('z t l w')

# %%
eq = (z**2 + 1)*l - 1 - (w/(z**2 + w**2))

# %%
solve(eq, l)
# Out:
# [(w**2 + w + z**2)/(w**2*z**2 + w**2 + z**4 + z**2)]

# %%
w = 1

# %%
inverse_laplace_transform((w**2 + w + z**2)/(w**2*z**2 + w**2 + z**4 + z**2), z, t)
# Out:
# (-t*cos(t)/2 + sin(t)/2)*Heaviside(t) + sin(t)*Heaviside(t)
